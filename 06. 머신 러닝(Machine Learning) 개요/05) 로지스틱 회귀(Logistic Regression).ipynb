# %% [markdown]
# # 1. 이진 분류(Binary Classification)
# 선형 회귀는 둘 중 하나의 선택지 중에서 정답을 고르는 이진 분류 문제에는 적합하지 않다.
#
# 시험 성적이 x라면, 합불 결과는 y이다.
#
# |score(x)|result(y)|
# |:---:|:---:|
# |45|불합격|
# |50|불합격|
# |55|불합격|
# |60|합격|
# |65|합격|
# |70|합격|
#
# ![image.png](attachment:image.png)
#
# 이러한 점들을 표현하는 그래프는 알파벳의 S자 형태로 표현된다. 이러한 x와 y의 관계를 표현하기 위해서는 직선을 표현하는 함수가 아니라 S자 형태를 표현하 수 있는 함수가 필요하다.
#
# 예측값을 0과 1 사이의 값을 가지도록 하면, 0과 1사이의 값을 확률로 해석하면 문제 풀기가 용이해진다. 최종 예측값이 0.5보다 작으면 0으로 예측했다고 판단하고, 0.5보다 크면 1로 예측했다고 판단한다.
#
# 시그모이드 함수(Sigmoid function) : 출력이 0과 1사이의 값을 가지면서 S자 형태로 그려지는 함수

# %% [markdown]
# # 2. 시그모이드 함수(Sigmoid function)
#
# ![image.png](attachment:image.png)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def sigmoid(x):
    return 1/(1+np.exp(-x))

x = np.arange(-5.0, 5.0, 0.1)
y = sigmoid(x)

plt.plot(x, y, 'g')
plt.plot([0,0],[1.0,0.0], ':') # 가운데 점선 추가
plt.title('Sigmoid Function')
plt.show()

# %%
x = np.arange(-5.0, 5.0, 0.1)
y1 = sigmoid(0.5*x)
y2 = sigmoid(x)
y3 = sigmoid(2*x)

plt.plot(x, y1, 'r', linestyle='--') # w의 값이 0.5일때
plt.plot(x, y2, 'g') # w의 값이 1일때
plt.plot(x, y3, 'b', linestyle='--') # w의 값이 2일때
plt.plot([0,0],[1.0,0.0], ':') # 가운데 점선 추가
plt.title('Sigmoid Function')
plt.show()

# %%
x = np.arange(-5.0, 5.0, 0.1)
y1 = sigmoid(x+0.5)
y2 = sigmoid(x+1)
y3 = sigmoid(x+1.5)

plt.plot(x, y1, 'r', linestyle='--') # x + 0.5
plt.plot(x, y2, 'g') # x + 1
plt.plot(x, y3, 'b', linestyle='--') # x + 1.5
plt.plot([0,0],[1.0,0.0], ':') # 가운데 점선 추가
plt.title('Sigmoid Function')
plt.show()

# %% [markdown]
# # 3. 비용 함수(Cost function)
#
# 로지스틱 회귀 또한 경사 하강법을 사용하여 가중치 w를 찾아내지만, 비용 함수로는 MSE를 사용하지 않는다.
#
# ![image.png](attachment:image.png)
#
# 로지스틱 회귀에서 MSE를 비용 함수로 사용하면, 경사 하강법을 사용하였을때 찾고자 하는 최솟값이 아닌 최소값에 빠질 가능성이 매우 높다. 이를 전체 함수에 걸쳐 최소값인 **글로벌 미니멈(Global Minimum)** 이 아닌 특정 구역에서 최소값인 **로컬 미니멈(Local Minimum)** 에 도달했다고 한다.
#
# ![image-2.png](attachment:image-2.png)
#
# 이때 로지스틱 회귀에서 찾아낸 비용 함수를 크로스 엔트로피(Cross Entropy)함수 라고 한다.
