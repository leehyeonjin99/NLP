# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras import optimizers

# %% [markdown]
# # 1. 다중 선형 회귀
#
# ![image-2.png](attachment:image-2.png)

# %%
X = np.array([[70,85,11], [71,89,18], [50,80,20], [99,20,10], [50,10,10]]) # 중간 고사, 기말 고사, 가산점 점수
y = np.array([73, 82 ,72, 57, 34]) # 최종 성적

model=Sequential()
model.add(Dense(1, input_dim=3, activation='linear'))

sgd=optimizers.SGD(0.0001)
model.compile(optimizer=sgd, loss='mse', metrics=['mse'])
model.fit(X, y, epochs=2000)
# Out:
# Epoch 1/2000
# 1/1 [==============================] - 0s 431ms/step - loss: 6356.7861 - mse: 6356.7861
# Epoch 2/2000
# 1/1 [==============================] - 0s 3ms/step - loss: 3680.2227 - mse: 3680.2227
# Epoch 3/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 2161.2280 - mse: 2161.2280
# Epoch 4/2000
# 1/1 [==============================] - 0s 4ms/step - loss: 1288.5643 - mse: 1288.5643
# Epoch 5/2000
# 1/1 [==============================] - 0s 3ms/step - loss: 780.6506 - mse: 780.6506
# Epoch 6/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 481.0135 - mse: 481.0135
# Epoch 7/2000
# 1/1 [==============================] - 0s 4ms/step - loss: 301.8181 - mse: 301.8181
# Epoch 8/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 193.2020 - mse: 193.2020
# Epoch 9/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 126.5103 - mse: 126.5103
# Epoch 10/2000
# ...

# %%
print(model.predict(X))
# Out:
# [[72.93367 ]
#  [81.975136]
#  [72.09364 ]
#  [57.11534 ]
#  [33.806297]]

# %%
print(model.predict([[20,99,10], [40,50,20]]))
# Out:
# [[57.90796 ]
#  [56.057938]]

# %% [markdown]
# # 2. 다중 로지스틱 회귀
#
# ![image.png](attachment:image.png)

# %%
X = np.array([[0, 0], [0, 1], [1, 0], [0, 2], [1, 1], [2, 0]])
y = np.array([0, 0, 0, 1, 1, 1])

model=Sequential()
model.add(Dense(1, input_dim=2, activation='sigmoid'))
model.compile(optimizer='sgd', loss='binary_crossentropy', metrics=['binary_accuracy'])

model.fit(X, y, epochs=2000)
# Out:
# Epoch 1/2000
# 1/1 [==============================] - 0s 344ms/step - loss: 0.7015 - binary_accuracy: 0.6667
# Epoch 2/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.7009 - binary_accuracy: 0.6667
# Epoch 3/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.7003 - binary_accuracy: 0.6667
# Epoch 4/2000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6997 - binary_accuracy: 0.6667
# Epoch 5/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.6992 - binary_accuracy: 0.6667
# Epoch 6/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.6986 - binary_accuracy: 0.6667
# Epoch 7/2000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6980 - binary_accuracy: 0.6667
# Epoch 8/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.6975 - binary_accuracy: 0.6667
# Epoch 9/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.6969 - binary_accuracy: 0.6667
# Epoch 10/2000
# ...

# %%
print(model.predict(X))
# Out:
# [[0.18286017]
#  [0.46017703]
#  [0.45658538]
#  [0.7645571 ]
#  [0.761943  ]
#  [0.75930893]]

# %% [markdown]
# # 3. 인공 신경망 다이어그램
# 다중 로지스틱 인공 신경망의 형태로 표현하면 다음과 같다. 즉, 로지스틱 회귀를 일종의 인공 신경망 구조로 해석해도 무방하다.
#
# ![image.png](attachment:image.png)
